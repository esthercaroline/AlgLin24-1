# %% [markdown]
# ## Questão 1
#
# Considere a matriz ```A``` apresentada abaixo:
#
# Calcule os autovalores e autovetores da matriz e responda:
#
# B - Qual o maior autovalor da matriz?
#
#
# C - Qual o autovetor correspondente ao maior autovalor da matriz?
#
#
# D - Qual o menor autovalor da matriz?
#
#
# E - Qual o autovetor correspondente ao menor autovalor da matriz?

# %%
import numpy as np

A = np.array([[0.50, 0.16], [0.59, 0.32]])

w, v = np.linalg.eig(A)

# print("Auto Valores")
# print(w)
# print("Auto Vetores")
# print(v)

B = w.T[0]
C = v.T[0]
D = w.T[-1]
E = v.T[-1]

# %% [markdown]
# ## Questão 2
#
# Calcule os autovalores e autovetores da matriz e responda:
#
# B - Qual o maior autovalor da matriz?
#
# C - Qual o autovetor correspondente ao maior autovalor da matriz? (coloque os elementos na mesma linha)

# %%
import numpy as np
import numpy as np

A = np.array([[0.35, 0.76, 0.22, 0.86, 0.86, 0.77, 0.11, 0.22], [0.79, 0.08, 0.90, 0.65, 0.28, 0.47, 0.68, 0.12], [0.02, 0.19, 0.01, 0.26, 0.21, 0.16, 0.22, 0.37], [0.24, 0.68, 0.73, 0.68, 0.42, 0.26, 0.52, 0.21], [0.74, 0.69, 0.58, 0.70, 0.72, 0.14, 0.96, 0.62], [0.82, 0.73, 0.87, 0.20, 0.09, 0.46, 0.73, 0.34], [0.68, 0.81, 0.46, 0.64, 0.47, 0.70, 0.70, 0.42], [0.12, 0.08, 0.78, 0.32, 0.47, 0.80, 0.29, 0.79]])

w, v = np.linalg.eig(A)

# print("Auto Valores")
# print(w)
# print("Auto Vetores")
# print(v)

B = w.T[0]
C = v.T[0]
C
# Out:
# array([0.38306459, 0.33370737, 0.13377002, 0.31392688, 0.46810992,
#        0.35391444, 0.43949664, 0.29650764])

# %% [markdown]
# ## Questão 3
#
# Considere os autovalores w e os autovetores v abaixo de modo que os valores na coluna v[:,i] são os autovetores correspondentes ao autovalor w[i].
#
# B - Qual a matriz ```A``` cujos autovalores são w e os autovetores v? (Dica: utilize np.diag para converter uma lista de números em uma matriz diagonal)

# %%
import numpy as np


# Pense que este W e V são os resultados de um linalg.eig(A)
v = np.array([[0.59352948, 0.82700895, -0.56344498], [0.71518516, -0.21790266, -0.37484387], [0.36909746, -0.51824186, 0.73622132]])
w = np.array([1.25409524, -0.35622488, -0.05787036])

w_ = np.diag(w)
B = v @ w_ @ np.linalg.inv(v)
B
# Out:
# array([[0.12999999, 0.68000001, 0.48999999],
#        [0.62999999, 0.37000001, 0.69999999],
#        [0.46      , 0.09000001, 0.34      ]])

# %% [markdown]
# # Question 1: Autovalores e Autovetores: Exercício 6

# %%
import numpy as np

v = np.array([[-0.59134872, -0.35412393, 0.55580228, 0.19897486, -0.29497267,  -0.29897640], [-0.46118078, -0.26190737, -0.03502328, -0.55757088, 0.17554200,  0.61301706], [-0.51585599, 0.00582689, -0.63090737, 0.07151755, 0.34949818,  -0.45667362], [0.38074559, -0.88655777, -0.13230546, 0.06071938, 0.19439553,  -0.10033402], [-0.06748766, 0.08856088, 0.33318249, 0.51361796, 0.73765031, 0.26203134], [-0.14828954, -0.11017759, -0.40410120, 0.61393706, -0.42203027,  0.49753901]])
