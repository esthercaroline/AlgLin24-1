# %% [markdown]
# # Exercício 1

# %% [markdown]
# Os autovalores w e os autovetores v abaixo foram calculados sobre uma matriz de covariância de um conjunto de dados. Sendo que os valores na coluna v[:,i] são os autovetores correspondentes ao autovalor w[i], responda:

# %% [markdown]
# Quantas features existiam no conjunto de dados?

# %%
import numpy as np

v = np.array([[-0.24433922, -0.71193154, 0.33284763, 0.53250019, -0.18091728,  -0.05749437, 0.04832546, 0.02712591], [-0.13692759, -0.10961522, 0.27405254, -0.49458838, -0.54737256,  0.55110323, -0.01821229, -0.21412542], [0.63398210, -0.45718703, 0.09752826, -0.40847890, 0.09037047,  -0.27556275, 0.35103951, -0.07314065], [0.57627881, 0.00954205, -0.06819122, 0.25151117, -0.38233932,  -0.03466468, -0.66568886, -0.09683554], [-0.08084690, 0.15012458, -0.16360847, -0.05652729, -0.66988167,  -0.42486584, 0.26278051, 0.49260257], [0.08935239, -0.04181403, 0.40692548, -0.18101687, 0.24042159,  0.18253417, -0.29488548, 0.78347531], [-0.36887503, -0.43116826, -0.45602394, -0.41822288, 0.08179340,  -0.25434179, -0.47279719, 0.01548675], [0.19217116, -0.24866660, -0.63216449, 0.17561370, -0.00823935,  0.58079575, 0.22674731, 0.28628153]])
w = np.array([1.62419111, 1.48445345, 0.19972983, 0.31083928, 1.10922762, 0.56540681, 0.72676706, 0.92071169])
v.shape[1]
# Out:
# 8

# %% [markdown]
# Apresente uma matriz de duas colunas onde cada uma contém os autovetores que devem ser utilizados para projetar os dados em duas dimensões:

# %%
dois_autovetores = v[:,:2]
dois_autovetores
# Out:
# array([[-0.24433922, -0.71193154],
#        [-0.13692759, -0.10961522],
#        [ 0.6339821 , -0.45718703],
#        [ 0.57627881,  0.00954205],
#        [-0.0808469 ,  0.15012458],
#        [ 0.08935239, -0.04181403],
#        [-0.36887503, -0.43116826],
#        [ 0.19217116, -0.2486666 ]])

# %% [markdown]
# # Exercício 2

# %% [markdown]
# Utilizando a Análise de Componentes Principais com duas componentes da biblioteca scikit-learn, apresente a matriz com os valores das componentes. Cada componente deve estar em uma coluna da matriz.

# %%
import numpy as np
from sklearn.decomposition import PCA

dados = np.array([[1.62021393, -1.53165084, 0.49572148, 1.15264704, 0.15346821,  -1.77777951], [-0.15079354, 1.17546831, 1.28218332, 0.64829227, 0.03445497,  -1.15861601], [-0.63030080, -2.04700511, -0.24799545, 0.32121870, -0.39306743,  -0.48538495], [0.23769377, 0.42732149, 0.41206527, 0.60426369, 1.36600844, 0.05519173], [0.57572070, -0.15525590, 1.16